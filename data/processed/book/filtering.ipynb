# %%
import pandas as pd

# %%
df_filtered=pd.read_csv("book_filtered_rating.csv")
df_user=pd.read_csv("book_user.csv")
df_info=pd.read_csv("book_info.csv")

# %%
df_filtered.shape
# Out:
# (2456, 4)

# %%
df_unfilter=pd.read_csv("book_rating.csv")

# %%
df_unfilter.shape
# Out:
# (1149780, 4)

# %%
df_filtered.head()
# Out:
#    User-ID        ISBN  Rating  book_id
# 0        2  0195153448     0.0     8968
# 1        7   034542252     0.0     8969
# 2        8  0002005018     2.5     8970
# 3        8  0060973129     0.0     8971
# 4        8  0374157065     0.0     8972

# %%
df_unfilter.head()
# Out:
#    User-ID        ISBN  Rating  book_id
# 0   276725  034545104X     0.0        1
# 1   276726  0155061224     2.5        2
# 2   276727  0446520802     0.0        3
# 3   276729  052165615X     1.5        4
# 4   276729  0521795028     3.0        5

# %%
# Out:
#   Cell In[9], line 1
#     df_user=
#             ^
# SyntaxError: invalid syntax
