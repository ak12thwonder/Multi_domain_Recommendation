# %%
import numpy as np 
import pandas as pd

# %%
df_book=pd.read_csv(r"E:\GitHub Repo's\Multi_domain_Recommendation\data\processed\book\book_user.csv")
# Out:
# C:\Users\aditya.kaushal\AppData\Local\Temp\ipykernel_95888\1908204672.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_book=pd.read_csv(r"E:\GitHub Repo's\Multi_domain_Recommendation\data\processed\book\book_user.csv")

# %%
df_book.head()
# Out:
#   User-ID   Age
# 0       1   NaN
# 1       2  18.0
# 2       3   NaN
# 3       4  17.0
# 4       5   NaN

# %%
df_movie.head()
# Out:
#    user_id  age gender  occupation zip_code age_group
# 0        1   24      M  technician    85711     18-24
# 1        2   53      F       other    94043     50-64
# 2        3   23      M      writer    32067     18-24
# 3        4   24      M  technician    43537     18-24
# 4        5   33      F       other    15213     25-34

# %%
df_movie=pd.read_csv(r"E:\GitHub Repo's\Multi_domain_Recommendation\data\processed\movie\movie_user.csv")

# %%
# 1. Keep only userID and age from both DataFrames
book_age = df_book[['User-', 'Age']].dropna().drop_duplicates()
movie_age = df_movie[['user_id', 'age']].dropna().drop_duplicates()

# 2. Merge on userID to compare ages
age_check = pd.merge(book_age, movie_age, on='userID', how='inner', suffixes=('_book', '_movie'))

# 3. Find where age is different
conflicting_ages = age_check[age_check['age_book'] != age_check['age_movie']]

# 4. Show result
print(f"Total conflicting userIDs: {conflicting_ages.shape[0]}")
print(conflicting_ages.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 # 1. Keep only userID and age from both DataFrames
# ----> 2 book_age = df_book[['userID', 'Age']].dropna().drop_duplicates()
#       3 movie_age = df_movie[['user_id', 'age']].dropna().drop_duplicates()
#       5 # 2. Merge on userID to compare ages
#
# File e:\GitHub Repo's\Multi_domain_Recommendation\venv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File e:\GitHub Repo's\Multi_domain_Recommendation\venv\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
# ...
