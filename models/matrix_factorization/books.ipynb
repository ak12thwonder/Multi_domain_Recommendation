# %%
import pandas as pd

# %%
df_rating=pd.read_csv(r"..\..\data\processed\book\book_filtered_rating.csv")

# %%
df_rating.head()
# Out:
#    User-ID        ISBN  Rating  book_id
# 0        2  0195153448     0.0     8968
# 1        7   034542252     0.0     8969
# 2        8  0002005018     2.5     8970
# 3        8  0060973129     0.0     8971
# 4        8  0374157065     0.0     8972
